# %%
#install depdendencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./venv/lib/python3.14/site-packages (0.116.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.14/site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in ./venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in ./venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
# make a request
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    

    message = client.messages.create(**params)
    for block in message.content:
        if block.type == "text":
            return block.text
 
question= "What's 2+2?"

prompt = f"""
Please answer the user's question:

{question}

Answer the question with ample detail
"""

messages = []

add_user_message(
    messages, 
    prompt,
)

answer = chat(messages, prompt)

answer
# Out:
# '# What is 2 + 2?\n\nThe answer is **4**.\n\n## Breaking It Down\n\nThis is a basic arithmetic problem involving **addition**, one of the four fundamental operations in mathematics (along with subtraction, multiplication, and division).\n\n### The Components\n- **2** — the first addend\n- **+** — the addition operator, indicating we are combining quantities\n- **2** — the second addend\n- **=** — the equals sign, showing the result of the operation\n- **4** — the sum\n\n### Why It Equals 4\n\nIf you start with a group of 2 items (say, 2 apples) and add another group of 2 items (2 more apples), you combine them into a single group. Counting the total items in that combined group gives you 4 apples.\n\nYou can visualize it like this:\n```\n🍎🍎 + 🍎🍎 = 🍎🍎🍎🍎\n```\n\n### Number Line Explanation\nAnother way to see it: start at the number 2 on a number line, then move 2 steps to the right (since addition means moving forward):\n```\n2 → 3 → 4\n```\nYou land on 4.\n\n### Formal Definition (Peano Arithmetic)\nIn more formal mathematics, addition is defined recursively. Using the successor function *S* (where *S(n)* means "the number after n"):\n- 2 + 2 = 2 + S(1) = S(2 + 1) = S(S(2 + 0)) = S(S(2)) = S(3) = 4\n\nThis confirms the result through the basic axioms of arithmetic.\n\n### Summary\nNo matter how you approach it — through counting objects, using a number line, or formal mathematical proof — the answer remains consistent:\n\n**2 + 2 = 4**'

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
# Start with an empty message list
messages = []

while True:
    #get user input
    user_input = input("> ")
    print(">", user_input)

    # Add the initial user question
    add_user_message(messages, user_input)

    # Get Claude's response
    answer = chat(messages)

    #add generated text to the list of messages
    add_assistant_message(messages, answer)

    #print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > pao mais torrada?
# ---
# # Pão ou Torrada? 🍞
#
# Depende do contexto! Veja as diferenças:
#
# ## Pão
# - **Vantagens:** mais macio, versátil, pode ser usado para sanduíches
# - **Calorias:** geralmente similar à torrada (a torragem não reduz muito as calorias)
# - **Textura:** macia
#
# ## Torrada
# - **Vantagens:** mais crocante, geralmente mais fácil de digerir para algumas pessoas, dura mais tempo antes de estragar
# - **Digestão:** o processo de tostar quebra um pouco os amidos, o que pode facilitar a digestão
# - **Textura:** crocante
#
# ## Na prática:
# - Se você quer algo mais **saudável e nutritivo**: escolha pão integral ou de fermentação natural (sourdough)
# - Se busca **praticidade e crocância**: torrada é ótima
# - **Calorias são parecidas** entre os dois, a diferença real está no tipo de pão (integral vs. branco) e nos acompanhamentos que você usa
#
# **Dica:** o que realmente importa é o que você coloca em cima! Abacate, ovo, queijo cottage são opções mais saudáveis que manteiga ou geleia açucarada.
#
# Você está pensando em algo específico, tipo dieta, digestão, ou só curiosidade mesmo? 😊
# ---
# > 2+2?
# ---
# # 2 + 2 = 4
#
# Uma continha simples! 😊 Precisa de mais alguma coisa?
# ---
# > +3?
# ---
# # 4 + 3 = 7
#
# Seguindo a sequência! Quer continuar? 😊
# ---
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[24], line 13
#       9     # Add the initial user question
#      10     add_user_message(messages, user_input)
#      11
#      12     # Get Claude's response
# ---> 13     answer = chat(messages)
#      14
#      15     #add generated text to the list of messages
#      16     add_assistant_message(messages, answer)
#
# Cell In[22], line 27, in chat(messages)
#      26 def chat(messages):
# ---> 27     message = client.messages.create(
#      28         model=model,
#      29         max_tokens=1000,
#      30         messages=messages,
#
# File ~/Apps/ClaudeCourse/venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Apps/ClaudeCourse/venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~/Apps/ClaudeCourse/venv/lib/python3.14/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Apps/ClaudeCourse/venv/lib/python3.14/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.6: user messages must have non-empty content'}, 'request_id': 'req_011CchX7gZHcQEv4X4GUPMhC'}
