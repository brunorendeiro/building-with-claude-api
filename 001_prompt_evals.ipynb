# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""


    messages = []
    add_user_message(messages,prompt)
    add_assistant_message(messages,"```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

#dataset

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results


with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Region Extraction Function\n\nHere's a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\n\ndef extract_region_from_s3_url(url: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Args:\n        url: S3 URL in format 's3://bucket-name.region.amazonaws.com'\n        \n    Returns:\n        Region code (e.g., 'us-east-1')\n        \n    Raises:\n        ValueError: If the URL format is invalid or region cannot be extracted\n    \"\"\"\n    # Pattern to match S3 URL and extract region\n    pattern = r's3://[a-z0-9\\-\\.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    match = re.search(pattern, url)\n    if match:\n        return match.group(1)\n    else:\n        raise ValueError(f\"Invalid S3 URL format: {url}\")\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test with various URL formats\n    test_urls = [\n        \"s3://my-bucket.us-east-1.amazonaws.com\",\n        \"s3://data-bucket.eu-west-1.amazonaws.com\",\n        \"s3://backup.ap-southeast-2.amazonaws.com\",\n        \"s3://archive-2024.ca-central-1.amazonaws.com\",\n    ]\n    \n    print(\"Testing S3 Region Extraction:\\n\")\n    for url in test_urls:\n        try:\n            region = extract_region_from_s3_url(url)\n            print(f\"URL: {url}\")\n            print(f\"Region: {region}\\n\")\n        except ValueError as e:\n            print(f\"Error: {e}\\n\")\n    \n    # Test with invalid URL\n    print(\"Testing with invalid URL:\")\n    try:\n        extract_region_from_s3_url(\"s3://invalid-bucket-url\")\n    except ValueError as e:\n        print(f\"Error caught: {e}\")\n```\n\n**Output:**\n```\nTesting S3 Region Extraction:\n\nURL: s3://my-bucket.us-east-1.amazonaws.com\nRegion: us-east-1\n\nURL: s3://data-bucket.eu-west-1.amazonaws.com\nRegion: eu-west-1\n\nURL: s3://backup.ap-southeast-2.amazonaws.com\nRegion: ap-southeast-2\n\nURL: s3://archive-2024.ca-central-1.amazonaws.com\nRegion: ca-central-1\n\nTesting with invalid URL:\nError caught: Invalid S3 URL format: s3://invalid-bucket-url\n```\n\n## Alternative Implementation (String Parsing)\n\nIf you prefer not to use regex:\n\n```python\ndef extract_region_from_s3_url(url: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL using string parsing.\n    \n    Args:\n        url: S3 URL in format 's3://bucket-name.region.amazonaws.com'\n        \n    Returns:\n        Region code (e.g., 'us-east-1')\n    \"\"\"\n    try:\n        # Remove 's3://' prefix\n        if not url.startswith('s3://'):\n            raise ValueError(\"URL must start with 's3://'\")\n        \n        url_without_prefix = url[5:]  # Remove 's3://'\n        \n        # Check if URL ends with '.amazonaws.com'\n        if not url_without_prefix.endswith('.amazonaws.com'):\n            raise ValueError(\"URL must end with '.amazonaws.com'\")\n        \n        # Remove '.amazonaws.com' suffix\n        url_without_suffix = url_without_prefix[:-14]  # Remove '.amazonaws.com'\n        \n        # Split by dots and extract region (should be second-to-last part)\n        parts = url_without_suffix.split('.')\n        \n        if len(parts) < 2:\n            raise ValueError(\"Invalid S3 URL format\")\n        \n        region = parts[-1",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com'. The function should return just the region code (e.g., 'us-east-1')."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 GetObject and PutObject\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3GetPutObjectAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-bucket/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: `2012-10-17` is the standard policy language version\n- **Statement**: Contains the permission rules\n- **Sid**: A descriptive identifier for the statement (optional but recommended)\n- **Effect**: `Allow` grants the specified permissions\n- **Action**: \n  - `s3:GetObject` - Allows reading/downloading objects\n  - `s3:PutObject` - Allows uploading/writing objects\n- **Resource**: `arn:aws:s3:::my-app-bucket/*` specifies all objects (`/*`) in the bucket `my-app-bucket`\n\n## Additional Options\n\nIf you need to extend this policy, consider adding:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3GetPutObjectAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\",\n        \"s3:DeleteObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-app-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucketAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": \"s3:ListBucket\",\n      \"Resource\": \"arn:aws:s3:::my-app-bucket\"\n    }\n  ]\n}\n```\n\nThis extended version also allows listing bucket contents and deleting objects if needed.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows a principal to perform GetObject and PutObject actions on all objects within a specific S3 bucket named 'my-app-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\n```regex\n^i-[a-z0-9]{17}$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix (required for all EC2 instance IDs) |\n| `[a-z0-9]` | Character class matching lowercase letters or digits |\n| `{17}` | Quantifier requiring exactly 17 characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid matches:\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g', invalid)\n- `i-0a1b2c3d4e5f67890` \u2705\n- `i-abcdef1234567890z` \u274c (contains 'z', invalid)\n- `i-1234567890abcdef0` \u2705\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[a-z0-9]{17}$/;\n\nconsole.log(pattern.test('i-1234567890abcdef0')); // true\nconsole.log(pattern.test('i-1234567890abcdef'));  // false (only 16 chars)\nconsole.log(pattern.test('I-1234567890abcdef0')); // false (uppercase I)\n```\n\n**Python:**\n```python\nimport re\n\npattern = r'^i-[a-z0-9]{17}$'\n\nprint(re.match(pattern, 'i-1234567890abcdef0'))  # Match object (valid)\nprint(re.match(pattern, 'i-1234567890abcdef'))   # None (invalid)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs. Instance IDs follow the pattern of 'i-' followed by exactly 17 alphanumeric characters (lowercase letters and digits only)."
#     },
#     "score": 10
#   }
# ]
